# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# %%
iris_data = load_iris()

# %%
X = iris_data.data
X.shape
# Out:
# (150, 4)

# %%
y = iris_data.target
y.shape
# Out:
# (150,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Initialize our tree model
clf = DecisionTreeClassifier()

# %%
# Fit our training dataset
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Now predict our tests dataset inorder to calculate accuracy
y_pred = clf.predict(X_test)

# %%
# Let's calculate our accuracy score
accuracy_score(y_test, y_pred)
# Out:
# 0.9666666666666667

# %%
from sklearn.tree import plot_tree

# %%
from matplotlib.pyplot import rcParams
rcParams['figure.figsize'] = 80, 50

plot_tree(clf, filled=True)
plt.show()

# %%
# plotting the pie chart
iris_df = pd.DataFrame(load_iris().data, columns=load_iris().feature_names)

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris_df['species'] = load_iris().target

# %%
species = iris_df['species'].value_counts()

# %%
load_iris().target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
fig = plt.figure(figsize=(6, 15))
colors = ('cyan', 'yellow', 'crimson')
data = iris_df['species'].value_counts()
explode = [0.08, 0.08, 0.08]
classes = ['Iris-setosa', 'Iris-versicolor', 'Iris-verginica']
data.plot(kind='pie', autopct='%0.2f%%', labels=classes, startangle=45, colors=colors, explode=explode, shadow=True)
plt.legend(title='Species')
plt.show()
